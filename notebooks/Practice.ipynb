# %%
from scipy.integrate import odeint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Book1.csv')
Tl = df['T_l']
Tv = df['T_v']
stages = df['Stages']
plt.plot(Tl, stages)
plt.plot(Tv, stages)
