# %%
from scipy.integrate import odeint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

f_Psat_H2O = lambda T: np.exp(72.55 + -7206.70 / T + -7.1385 * np.log(T) + 4.05e-6 * T ** 2)
T = np.linspace(273.15, 350 + 273.15, 101)

plt.plot(T, f_Psat_H2O(T)/1000)
plt.yscale('log')
